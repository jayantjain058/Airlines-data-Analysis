# %% [markdown]
# # AIRLINES PROJECT

# %%
#importing various libraries 
#dataclean
#eda + data visualisation
#insights
#summary
#conclusion
#recomendation

import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # importing CSV file

# %%
data=pd.read_csv("mark.csv")

# %%
data
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %% [markdown]
# # Data Analysis

# %%
#this helps to analyse data and get information about the datatype of each columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
#this function helps us to get the overview of the table in the first five tables 
data.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
data.tail()
# Out:
#         Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 103899      103899  94171  Female  disloyal Customer   23  Business travel
# 103900      103900  73097    Male     Loyal Customer   49  Business travel
# 103901      103901  68825    Male  disloyal Customer   30  Business travel
# 103902      103902  54173  Female  disloyal Customer   22  Business travel
# 103903      103903  62567    Male     Loyal Customer   27  Business travel
#
#            Class  Flight Distance  Inflight wifi service  \
# 103899       Eco              192                      2
# 103900  Business             2347                      4
# 103901  Business             1995                      1
# 103902       Eco             1000                      1
# 103903  Business             1723                      1
#
#         Departure/Arrival time convenient  ...  Inflight entertainment  \
# 103899                                  1  ...                       2
# ...

# %%
# this helps us to descibe data in terms of their mean mode and quartiles
data.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %%
# to check the duplicate values in  each columns 
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103899    False
# 103900    False
# 103901    False
# 103902    False
# 103903    False
# Length: 103904, dtype: bool

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, Gender, Customer Type, Age, Type of Travel, Class, Flight Distance, Inflight wifi service, Departure/Arrival time convenient, Ease of Online booking, Gate location, Food and drink, Online boarding, Seat comfort, Inflight entertainment, On-board service, Leg room service, Baggage handling, Checkin service, Inflight service, Cleanliness, Departure Delay in Minutes, Arrival Delay in Minutes, satisfaction]
# Index: []
#
# [0 rows x 25 columns]

# %%
# this function gives exact detail of the where the null values are present in the table 
data.isna()
# Out:
#         Unnamed: 0     id  Gender  Customer Type    Age  Type of Travel  \
# 0            False  False   False          False  False           False
# 1            False  False   False          False  False           False
# 2            False  False   False          False  False           False
# 3            False  False   False          False  False           False
# 4            False  False   False          False  False           False
# ...            ...    ...     ...            ...    ...             ...
# 103899       False  False   False          False  False           False
# 103900       False  False   False          False  False           False
# 103901       False  False   False          False  False           False
# 103902       False  False   False          False  False           False
# 103903       False  False   False          False  False           False
#
#         Class  Flight Distance  Inflight wifi service  \
# ...

# %%
#this finction gives how many element are null in each column of table
data.isna().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
# this heatmap gives us information of where the data is null . the minute white line shows the same .
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data["Arrival Delay in Minutes"].isna().sum()
# Out:
# 310

# %%
data.shape
# Out:
# (103904, 25)

# %%
# to check the type of customers
data["Customer Type"].unique()
# Out:
# array(['Loyal Customer', 'disloyal Customer'], dtype=object)

# %%
# to check how many loyal customer are there
data["Customer Type"].isin(["Loyal Customer"]).sum()
# Out:
# 84923

# %%
# to check how many disloyal customer are there
data["Customer Type"].isin(["disloyal Customer"]).sum()
# Out:
# 18981

# %%
data
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %%
# to get the section or column of overall facility of that particular airlines

data["Overall"]=(data["Inflight wifi service"]+ data["Departure/Arrival time convenient"]+data["Inflight entertainment"]+data["On-board service"]+data["Leg room service"]
+data["Baggage handling"]+data["Checkin service"]+ data["Inflight service"]+ data["Cleanliness"])/9

# %%
# this column got created which gives the overall mean of all the facility presented pn airport 
data["Overall"]
# Out:
# 0         4.111111
# 1         2.333333
# 2         3.666667
# 3         2.888889
# 4         3.222222
#             ...
# 103899    2.222222
# 103900    4.666667
# 103901    3.222222
# 103902    2.555556
# 103903    2.111111
# Name: Overall, Length: 103904, dtype: float64

# %%
# to get mean of the column data which is named "Overall "
np.mean(data["Overall"])
# Out:
# 3.3049396023679978

# %%
data
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %%
# hence there are no duplicate values
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, Gender, Customer Type, Age, Type of Travel, Class, Flight Distance, Inflight wifi service, Departure/Arrival time convenient, Ease of Online booking, Gate location, Food and drink, Online boarding, Seat comfort, Inflight entertainment, On-board service, Leg room service, Baggage handling, Checkin service, Inflight service, Cleanliness, Departure Delay in Minutes, Arrival Delay in Minutes, satisfaction, Overall]
# Index: []
#
# [0 rows x 26 columns]

# %%
# to fill the null values in the column named "Arrival Delay in Minutes"
data["Arrival Delay in Minutes"].fillna(np.mean(data["Arrival Delay in Minutes"]) , inplace = True)
# Out:
# C:\Users\jayan\AppData\Local\Temp\ipykernel_22508\1662254746.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Arrival Delay in Minutes"].fillna(np.mean(data["Arrival Delay in Minutes"]) , inplace = True)

# %%
#hene the null value got replaced with the mean value of that particular columns
data["Arrival Delay in Minutes"].isna().sum()
# Out:
# 0

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
# hence the null values got removed perfectly....

# %%
data
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %%
# to find the max distance from the total distances travelled 

temp=0
for i in data["Flight Distance"]:
    if i > temp:
        temp=i
 

print(temp)
a=data[data["Flight Distance"]==temp]
print(a)
# Out:
# 4983
#        Unnamed: 0     id  Gender   Customer Type  Age   Type of Travel  \
# 2847         2847  31870  Female  Loyal Customer   63  Personal Travel
# 18434       18434  31876  Female  Loyal Customer   31  Business travel
# 19755       19755  31871  Female  Loyal Customer   50  Business travel
# 33094       33094  31878  Female  Loyal Customer   29  Personal Travel
# 46848       46848  31812    Male  Loyal Customer   42  Business travel
# 64631       64631  31875  Female  Loyal Customer   52  Business travel
# 64791       64791  31873  Female  Loyal Customer   50  Business travel
# 67767       67767  31880    Male  Loyal Customer   67  Personal Travel
# 74837       74837  31813  Female  Loyal Customer   37  Business travel
# 79574       79574  31817    Male  Loyal Customer   38  Business travel
# 80746       80746  31879  Female  Loyal Customer   47  Personal Travel
# 95982       95982  31881  Female  Loyal Customer   62  Personal Travel
#
# ...

# %%
# The overall experience of people that have travelled the most

# %% [markdown]
# # Data Visualisation

# %%
sns.countplot(data["satisfaction"])
# Out:
# <Axes: xlabel='count', ylabel='satisfaction'>

# %%
data[data["Class"]=="Eco"]["Class"]
# Out:
# 5         Eco
# 6         Eco
# 9         Eco
# 10        Eco
# 12        Eco
#          ...
# 103895    Eco
# 103896    Eco
# 103898    Eco
# 103899    Eco
# 103902    Eco
# Name: Class, Length: 46745, dtype: object

# %%
# using  matplotlib to draw graph between on board service and inflight service 
plt.scatter(data["On-board service"], data["Inflight service"])
plt.xlabel("outside")
plt.ylabel("inflight")
plt.title("total proportion")
plt.show()

# %%
sns.boxplot(data=data,x="Food and drink",  y ="Gate location")
# Out:
# <Axes: xlabel='Food and drink', ylabel='Gate location'>

# %%
sns.violinplot(data=data,x="Leg room service" , y="Baggage handling")
# Out:
# <Axes: xlabel='Leg room service', ylabel='Baggage handling'>

# %%
# hence the finalised data looks like this 
data
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...
